# %% [markdown]
# ## Part 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import rdkit
from rdkit import Chem
from rdkit import DataStructs
from rdkit.Chem import AllChem
# %matplotlib inline

# %% [markdown]
# ### Molecules as Strings: SMILES notation
# Simplified Molecular-Input Line-Entry System (SMILES) is a string representation of a molecule.<br>
# RDKIT is a cheminformatics package with numerous modules for working with chemical data.

# %%
smi = "O=C(O)c1ccc(N2CCC(Oc3ccccc3C(F)(F)F)CC2)nn1"

# %%
mol_from_smi = Chem.MolFromSmiles(smi)
mol_from_smi

# %%
smi_from_mol = Chem.MolToSmiles(mol_from_smi)
smi_from_mol
# Out:
# 'O=C(O)c1ccc(N2CCC(Oc3ccccc3C(F)(F)F)CC2)nn1'

# %% [markdown]
# ### Load Datasets

# %%
# labeled data
D_s = pd.read_csv('data/D_s_SCD1_L.csv')
D_s.head()
# Out:
#                                               SMILES  activity
# 0        O=C(O)c1ccc(N2CCC(Oc3ccccc3C(F)(F)F)CC2)nn1         0
# 1  O=C(NCC1CC1)c1ccc(N2CCN(C(=O)c3ccccc3C(F)(F)F)...         0
# 2  O=C(O)c1cncc(-c2ccc(N3CCC(Oc4ccccc4C(F)(F)F)CC...         0
# 3  O=C(O)CCCCCc1nc(-c2cn(Cc3cc(Br)c(Br)c(Br)c3)nn...         0
# 4     Cc1ccc(C(=O)Nc2ncc(Cc3cccc(C(F)(F)F)c3)s2)cc1C         0

# %%
D_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 642 entries, 0 to 641
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SMILES    642 non-null    object
#  1   activity  642 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 10.2+ KB

# %%
plt.figure(figsize = (8, 6))
plt.title(f'Class label distribution for labeled data')
plt.ylabel('No. of datapoints')
plt.xlabel('activity')
sns.countplot(x = D_s['activity'])
plt.grid()

# %%
# unlabeled data
D_u = pd.read_csv('data/D_u_SCD1_L.csv')
D_u.head()
# Out:
#                                               SMILES
# 0  CC1(C)Cc2c(C#N)c(OCC(=O)c3ccccc3)nc(-c3ccoc3)c...
# 1        CC(Sc1ncnc2sc(-c3ccccc3)cc12)C(=O)NCC1CCCO1
# 2    CCC1C(=O)NCCN1C(=O)c1ccc2nc(Cc3cccc(Cl)c3)oc2c1
# 3  O=C(c1ccco1)N1CCCC(c2nc(=O)c3nnn(Cc4c(Cl)cccc4...
# 4                CN(CC=Cc1ccc(Cl)cc1)Cc1cccc2ccccc12

# %%
D_u.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851726 entries, 0 to 851725
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   SMILES  851726 non-null  object
# dtypes: object(1)
# memory usage: 6.5+ MB

# %%
# randomly pick datapoints to generate the same size dataset as D_s
n_u_samp = (D_s.count()[0])*4
indices = np.random.randint(low = 0, high = n_u_samp, size = (n_u_samp,))

# %%
D_u = D_u.iloc[indices].copy()
D_u.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2568 entries, 2283 to 991
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SMILES  2568 non-null   object
# dtypes: object(1)
# memory usage: 40.1+ KB

# %%
D_u.reset_index(drop = True, inplace = True)
D_u.tail(10)
# Out:
#                                                  SMILES
# 2558  CC(CCC(O)C(C)(C)O)C1CCC2(C)C3CC=C4C(CCC(O)C4(C...
# 2559          CSc1nn(-c2c(Cl)cc(C(F)(F)F)cc2Cl)c(N)c1Br
# 2560               O=C(NCc1cccs1)c1nn(-c2ccccc2Cl)nc1CO
# 2561  COc1ccc(-c2ccc(COC3COc4nc([N+](=O)[O-])cn4C3)c...
# 2562      CCC(C)NC(=O)c1nc(C)c(C)nc1C(=O)Nc1cc(Cl)ccc1C
# 2563  O=c1c2c(Nc3ccc(Cl)cc3)nn(-c3ccccc3)c2nc(Nc2ccc...
# 2564  CC1(C)CC(=O)C(=CNc2ccc(O)c(NC=C3C(=O)CC(C)(C)C...
# 2565  CCCn1c(O)c2ccc(C(=O)N3CCN(c4ccccc4OC)CC3)cc2nc1=S
# 2566    COc1ccc(S(=O)(=O)N2CCCC(C(=O)NCc3ccco3)C2)cc1Cl
# 2567    COc1cc(OC)c(C2CC(C)(O)C3CC=C(C)C(O)C3O2)c(OC)c1

# %% [markdown]
# ### Generating Molecular Fingerprints
#
# RDKIT offers 3 different ways to convert SMILES notation into bit vectors through special types of molecular embedding methods known as fingerprints. These methods were initally created for substructure matching but are now used for a variety of applications such as classification, clustering, etc. Similar molecules will have similar substructures in the bit vectors: <br>
#
# 1. Topological fingerprints: These are rule-based path subtype fingerprints where each subsection(typically 4-5 bits long) represents a specific chemical structure/pattern. Since this uses bonds and path based structures, only linear structures are taken into account. maxPath defines how many bonds represent a single sub-structure. Embedding space size = 1024. More information can be found at: https://www.daylight.com/dayhtml/doc/theory/theory.finger.html<br>
#
# 2. Morgan/ECFP fingerprints: These are rule-based circular subtype fingerprints explicitly designed to capture features that are relevant to activity. A single dimension corresponds to a structure. A structure is defined by an atom and its neighboring atoms in a circular area. Embedding space size = 300 to 1024. More information can be found at: https://docs.chemaxon.com/display/docs/extended-connectivity-fingerprint-ecfp.md#:~:text=Extended%2DConnectivity%20Fingerprints%20(ECFPs),a%20wide%20variety%20of%20applications. <br>
#
# 3. Atom-pair & topological torsion: These are linear structure based fingerprints where each dimension represents a specific sub-structure in the molecule. A structure is defined a linear sequence of 2(atom-pair) or four(topological torsion) consecutively bonded non-hydrogen atoms. Embedding space size = 1024. <br>
#
# More information regarding molecualr fingerprints can be found at: https://www.rdkit.org/docs/RDKit_Book.html#id27

# %%
# create dictionary to reference index to fingerprint type
fingerprint_name = {0: 'Topological fingerprints',
                    1: 'Morgan fingerprints',
                    2: 'Atompair fingerprints',
                    3: 'Topological Torsion fingerprints'}

def get_fp_arr(fp):
    array = np.zeros((0,), dtype = bool)
    DataStructs.ConvertToNumpyArray(fp, array)
    return array

def get_topological_fp(mol):
    fpgen = AllChem.GetRDKitFPGenerator(maxPath=3, fpSize=1024)
    return get_fp_arr(fpgen.GetFingerprint(mol))    

def get_morgan_fp(mol):
    fpgen = AllChem.GetMorganGenerator(radius=2, fpSize=300)
    return get_fp_arr(fpgen.GetFingerprint(mol))

def get_atompair_fp(mol):
    fpgen = AllChem.GetAtomPairGenerator(countSimulation=False, fpSize=1024)
    return get_fp_arr(fpgen.GetFingerprint(mol))

def get_toptorsion_fp(mol):
    fpgen = AllChem.GetTopologicalTorsionGenerator(countSimulation=False, fpSize=1024)
    return get_fp_arr(fpgen.GetFingerprint(mol))


# takes a series of smiles and returns a list containing
# 4 different dataframes for 4 different fingerprints
def get_fingerprints(smiles_ser):
    fp_list = []

    # convert series to list
    smiles_list = smiles_ser.tolist()

    # convert smiles to mols
    mols_list = [Chem.MolFromSmiles(smi) for smi in smiles_list]

    # get topological fingerprints
    top_list = [get_topological_fp(mol) for mol in mols_list]
    top_df = pd.DataFrame(np.array(top_list, dtype=bool))
    fp_list.append(top_df)

    # get morgan fingerprints
    mor_list = [get_morgan_fp(mol) for mol in mols_list]
    mor_df = pd.DataFrame(np.array(mor_list, dtype=bool))
    fp_list.append(mor_df)

    # atompair fingerprints
    ap_list = [get_atompair_fp(mol) for mol in mols_list]
    ap_df = pd.DataFrame(np.array(ap_list, dtype=bool))
    fp_list.append(ap_df)
    
    # topological torsion
    tor_list = [get_toptorsion_fp(mol) for mol in mols_list]
    tor_df = pd.DataFrame(np.array(tor_list, dtype=bool))
    fp_list.append(tor_df)


    return fp_list

# %% [markdown]
# #### Train/Test split on labeled data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(D_s['SMILES'], D_s['activity'],
                                                    test_size=0.25, stratify = D_s['activity'])

# %% [markdown]
# #### Get fingerprints for training, test and unlabeled data

# %%
X_train_fps_s = get_fingerprints(X_train)
X_test_fps = get_fingerprints(X_test)
X_train_fps_u = get_fingerprints(D_u['SMILES'])
y_train_all_views = [y_train, y_train, y_train, y_train]

# %% [markdown]
# #### Add a unique identifier column separate from index to identify each datapoint

# %%
for i, df_u in enumerate(X_train_fps_u):   
    X_train_fps_u[i] = X_train_fps_u[i].reset_index()
    X_train_fps_u[i] = X_train_fps_u[i].rename(columns = {'index': 'id'})

# %% [markdown]
# #### Helper functions

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score, f1_score

# %%
# create list to store hyperparameters for all models
model_params = []

def set_best_model_params():
    # random gird will be for hyperparameter tuning
    random_grid = {
        'n_neighbors': [5, 10, 12, 15, 17, 20, 22, 25, 27, 30, 32, 35, 37, 40],
        'weights': ['uniform', 'distance'],
        'metric': ['jaccard', 'dice']
    }

    # clear list if necessary
    if len(model_params) > 0:
        model_params.clear()

    # cross validation to find good hyperparameters
    knn_c = KNeighborsClassifier()
    for i, X_train_fp in enumerate(X_train_fps_s):
        knn_cv = RandomizedSearchCV(estimator=knn_c, param_distributions=random_grid, n_iter=25, verbose=1)
        knn_cv.fit(X_train_fp, y_train_all_views[i])
        print(f'{knn_cv.best_params_}\n')
        model_params.append(knn_cv.best_params_)


# returns min of the total number of unlabeled samples remaining in each view
def get_min_unlabeled_data_count():
    samples_count_list_u = [df.count()[0] for df in X_train_fps_u]
    samples_count_list_s = [df.count()[0] for df in X_train_fps_s]
    print(f'The number of labeled samples: {samples_count_list_s}.')
    print(f'The number of unlabeled samples remaning: {samples_count_list_u}.')
    return min(samples_count_list_u), samples_count_list_u, samples_count_list_s


# trains the model on labeled data
def train_models(cv_params):
    # fit final models
    final_models = []
    for i, params in enumerate(cv_params):
        knn_final = KNeighborsClassifier(**params)
        knn_final.fit(X_train_fps_s[i], y_train_all_views[i])
        final_models.append(knn_final)

    return final_models


# gets indices and prediction for 'n' most confident predictions in each view
def get_best_n_prediction_indices(knn_models, n_values):
    # initialize list to store most confident indices and labels for each view
    ids_list = []
    labels_list = []

    for i, val in enumerate(knn_models):
        # get number of samples in unlabeled data
        n_samples = X_train_fps_u[i].shape[0]

        # get predictions and prediction probability
        X_train_u = X_train_fps_u[i][X_train_fps_u[i].columns[1:]]
        y_pred_u = knn_models[i].predict(X_train_u)
        y_pred_prob_u = knn_models[i].predict_proba(X_train_u)[np.arange(0, n_samples), y_pred_u]

        # get indices and labels of datapoints with most confident predictions
        max_prob_indices = np.argsort(y_pred_prob_u)[::-1][:n_values]
        max_prob_labels = y_pred_u[max_prob_indices]

        # get id values corresponding to the indices
        max_prob_ids = X_train_fps_u[i].iloc[max_prob_indices]['id'].values

        ids_list.append(max_prob_ids)
        labels_list.append(max_prob_labels)

    return ids_list, labels_list


# given a list of ids and predicted labels for each view from the unlabeled data
# adds datapoints to the training data
# predcitions made by one model in a single view are added to training data in all other views
def add_unlabeled_data(ids_list, labels_list):
    for i in range(len(ids_list)):
        # make copy
        ids_to_use = ids_list.copy()
        labels_to_use = labels_list.copy()

        # remove ith indices list and labels list
        ids_to_use.pop(i)
        labels_to_use.pop(i)

        # create a single array
        ids_arr = (np.array(ids_to_use)).flatten()
        labels_arr = (np.array(labels_to_use)).flatten()

        # out of all ids only ids present in the current
        # view's df can be used
        all_valid_ids = X_train_fps_u[i]['id'].values
        valid_indices = [val in all_valid_ids for val in ids_arr]

        # get valid values
        valid_ids_arr = ids_arr[valid_indices]
        valid_labels_arr = labels_arr[valid_indices]

        # remove duplicate values in ids and labels
        unique_ids = []
        unique_indices = []
        for val in valid_ids_arr:
            if val not in unique_ids:
                unique_ids.append(val)
                unique_indices.append(True)
            else:
                unique_indices.append(False)

        # get unique values
        final_ids_arr = valid_ids_arr[unique_indices]
        final_labels_arr = valid_labels_arr[unique_indices]

        # create dataframe to concatenate
        smiles_ser = (X_train_fps_u[i].loc[X_train_fps_u[i]['id'].isin(final_ids_arr)]).reset_index(drop=True)
        smiles_ser.drop('id', inplace = True, axis = 1)
        labels_ser = pd.Series(final_labels_arr, name='acitvity')
        df_to_add = pd.concat([smiles_ser, labels_ser], axis=1)

        # concatenate to labeled data and reset indices
        X_train_fps_s[i] = pd.concat([X_train_fps_s[i], df_to_add[df_to_add.columns[:-1]]], axis=0)
        X_train_fps_s[i].reset_index(inplace=True, drop=True)

        y_train_all_views[i] = pd.concat([y_train_all_views[i], df_to_add['acitvity']])
        y_train_all_views[i].reset_index(inplace=True, drop=True)

        # remove added data from unlabeled df
        indices_to_drop = (X_train_fps_u[i][X_train_fps_u[i]['id'].isin(final_ids_arr)]).index
        X_train_fps_u[i].drop(index = indices_to_drop, axis=0, inplace=True, errors='ignore')
        X_train_fps_u[i].reset_index(inplace = True, drop = True)


# prints test accuracy values given predictions and true value
def print_individual_test_accuracies(models_list, verbose = 0):
    
    # get prediction and accuracy for each model
    for i, model in enumerate(models_list):
        y_pred = model.predict(X_test_fps[i])
        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        if verbose == 1:
            print(f'Model {i + 1}: Accuracy: {acc:0.3f} and F1-score: {f1:0.3f}.')
    
    # print mean values
    avg_acc = np.mean(np.array(acc))
    avg_f1 = np.mean(np.array(f1))
    
    if verbose == 1:
        print(f'\nAverage test accuracy: {avg_acc:0.3f} \nAverage F1-score: {avg_f1:0.3f}\n')
    
    return avg_acc, avg_f1

# %% [markdown]
# ### Test Accuracy with Supervised Learning (KNN)
# For this part, 4 separate models will be trained using 4 different fingerprints and test accuracy will be obtained.

# %%
# train models for each view on the labeled data
set_best_model_params()
sup_models = train_models(model_params)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'uniform', 'n_neighbors': 15, 'metric': 'jaccard'}
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'distance', 'n_neighbors': 10, 'metric': 'dice'}
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'distance', 'n_neighbors': 10, 'metric': 'dice'}
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'distance', 'n_neighbors': 35, 'metric': 'jaccard'}

# %%
# get test accuracy
__, __ = print_individual_test_accuracies(sup_models, verbose = 1)
# Out:
# Model 1: Accuracy: 0.745 and F1-score: 0.809.
# Model 2: Accuracy: 0.764 and F1-score: 0.816.
# Model 3: Accuracy: 0.739 and F1-score: 0.794.
# Model 4: Accuracy: 0.739 and F1-score: 0.800.
#
# Average test accuracy: 0.739
# Average F1-score: 0.800

# %% [markdown]
# ### Semi-supervised multiview training using unlabeled data
# 1. Models will be trained on labeled data and used to make predictions on unlabeled data.
# 2. 20 of the most confident predictions for each view and their labels will be added to labeled data in other views.
# 3. Models will be re-tained on the updated labeled dataset and these steps will be repeated until there is no unlabeled data left or no valid datapoints can be added.

# %%
# runs multiview training using 'n_values' from the unlabeled data each iteration
def multi_view_training(n_values):
    # initialize list to store combined test acc
    # combined training acc not calculated as training data is not the same for different views
    test_acc = []
    test_f1 = []
    i_count = 0  # to count iterations

    # get the minimum number of samples in unlabeled data and whether
    # new data is being added
    min_samp_count_u, u_count_list_prev, s_count_list_prev = get_min_unlabeled_data_count()

    # run loop as long as there's enough unlabeled data
    while min_samp_count_u >= n_values:
        
        # train model and get test accuracy scores
        models_list = train_models(model_params)
        acc, f1_sc = print_individual_test_accuracies(models_list)
        test_acc.append(acc)
        test_f1.append(f1_sc)

        # get prediction on unlabeled data and add 'n' most confident datapoints to labeled data
        ids_list, labels_list = get_best_n_prediction_indices(models_list, n_values)
        add_unlabeled_data(ids_list, labels_list)
        
        min_samp_count_u, u_count_list_curr, _ = get_min_unlabeled_data_count()

        # if the algorithm has converged retrain model with different parameters
        if u_count_list_curr == u_count_list_prev: 
            print(f'The algorithm has converged for one or more views. Getting new model parameters.')
            set_best_model_params()
            n_values += 2
            
            # get prediction on unlabeled data and add 'n' most confident datapoints to labeled data
            ids_list, labels_list = get_best_n_prediction_indices(models_list, n_values)
            add_unlabeled_data(ids_list, labels_list)

            min_samp_count_u, u_count_list_curr, _ = get_min_unlabeled_data_count()

            # if the algoritm is still stuck even after updating the parameters, break
            if u_count_list_curr == u_count_list_prev:
                break
        else:
            u_count_list_prev = u_count_list_curr
        
        # increase iteration count
        i_count += 1
        print(f'Iteration {i_count} completed.\n')

    return models_list, test_acc, test_f1

# %%
# get final models and test acuuracy scores
n = 20
final_models_list, test_acc_list, test_f1_list = multi_view_training(n)
# Out:
# The number of labeled samples: [481, 481, 481, 481].
# The number of unlabeled samples remaning: [2568, 2568, 2568, 2568].
# The number of labeled samples: [539, 540, 540, 540].
# The number of unlabeled samples remaning: [2510, 2509, 2509, 2509].
# Iteration 1 completed.
#
# The number of labeled samples: [584, 585, 580, 583].
# The number of unlabeled samples remaning: [2465, 2464, 2469, 2466].
# Iteration 2 completed.
#
# The number of labeled samples: [618, 614, 606, 615].
# The number of unlabeled samples remaning: [2431, 2435, 2443, 2434].
# Iteration 3 completed.
#
# The number of labeled samples: [642, 635, 624, 641].
# The number of unlabeled samples remaning: [2407, 2414, 2425, 2408].
# Iteration 4 completed.
#
# The number of labeled samples: [656, 649, 640, 658].
# The number of unlabeled samples remaning: [2393, 2400, 2409, 2391].
# Iteration 5 completed.
#
# The number of labeled samples: [667, 661, 650, 669].
# The number of unlabeled samples remaning: [2382, 2388, 2399, 2380].
# Iteration 6 completed.
#
# The number of labeled samples: [678, 670, 660, 679].
# The number of unlabeled samples remaning: [2371, 2379, 2389, 2370].
# Iteration 7 completed.
#
# The number of labeled samples: [689, 685, 674, 697].
# The number of unlabeled samples remaning: [2360, 2364, 2375, 2352].
# Iteration 8 completed.
#
# The number of labeled samples: [701, 697, 687, 715].
# The number of unlabeled samples remaning: [2348, 2352, 2362, 2334].
# Iteration 9 completed.
#
# The number of labeled samples: [712, 708, 701, 726].
# The number of unlabeled samples remaning: [2337, 2341, 2348, 2323].
# Iteration 10 completed.
#
# The number of labeled samples: [718, 717, 714, 738].
# The number of unlabeled samples remaning: [2331, 2332, 2335, 2311].
# Iteration 11 completed.
#
# The number of labeled samples: [725, 720, 722, 745].
# The number of unlabeled samples remaning: [2324, 2329, 2327, 2304].
# Iteration 12 completed.
#
# The number of labeled samples: [734, 730, 734, 757].
# The number of unlabeled samples remaning: [2315, 2319, 2315, 2292].
# Iteration 13 completed.
#
# The number of labeled samples: [746, 745, 747, 772].
# The number of unlabeled samples remaning: [2303, 2304, 2302, 2277].
# Iteration 14 completed.
#
# The number of labeled samples: [754, 753, 757, 783].
# The number of unlabeled samples remaning: [2295, 2296, 2292, 2266].
# Iteration 15 completed.
#
# The number of labeled samples: [760, 767, 771, 795].
# The number of unlabeled samples remaning: [2289, 2282, 2278, 2254].
# Iteration 16 completed.
#
# The number of labeled samples: [767, 771, 777, 803].
# The number of unlabeled samples remaning: [2282, 2278, 2272, 2246].
# Iteration 17 completed.
#
# The number of labeled samples: [771, 777, 782, 809].
# The number of unlabeled samples remaning: [2278, 2272, 2267, 2240].
# Iteration 18 completed.
#
# The number of labeled samples: [782, 790, 800, 822].
# The number of unlabeled samples remaning: [2267, 2259, 2249, 2227].
# Iteration 19 completed.
#
# The number of labeled samples: [792, 804, 813, 830].
# The number of unlabeled samples remaning: [2257, 2245, 2236, 2219].
# Iteration 20 completed.
#
# The number of labeled samples: [805, 819, 830, 846].
# The number of unlabeled samples remaning: [2244, 2230, 2219, 2203].
# Iteration 21 completed.
#
# The number of labeled samples: [811, 831, 843, 858].
# The number of unlabeled samples remaning: [2238, 2218, 2206, 2191].
# Iteration 22 completed.
#
# The number of labeled samples: [823, 844, 861, 873].
# The number of unlabeled samples remaning: [2226, 2205, 2188, 2176].
# Iteration 23 completed.
#
# The number of labeled samples: [833, 854, 879, 889].
# The number of unlabeled samples remaning: [2216, 2195, 2170, 2160].
# Iteration 24 completed.
#
# The number of labeled samples: [841, 861, 890, 899].
# The number of unlabeled samples remaning: [2208, 2188, 2159, 2150].
# Iteration 25 completed.
#
# The number of labeled samples: [853, 869, 906, 914].
# The number of unlabeled samples remaning: [2196, 2180, 2143, 2135].
# Iteration 26 completed.
#
# The number of labeled samples: [873, 890, 932, 934].
# The number of unlabeled samples remaning: [2176, 2159, 2117, 2115].
# Iteration 27 completed.
#
# The number of labeled samples: [883, 902, 949, 947].
# The number of unlabeled samples remaning: [2166, 2147, 2100, 2102].
# Iteration 28 completed.
#
# The number of labeled samples: [891, 909, 958, 959].
# The number of unlabeled samples remaning: [2158, 2140, 2091, 2090].
# Iteration 29 completed.
#
# The number of labeled samples: [905, 924, 975, 977].
# The number of unlabeled samples remaning: [2144, 2125, 2074, 2072].
# Iteration 30 completed.
#
# The number of labeled samples: [925, 942, 997, 994].
# The number of unlabeled samples remaning: [2124, 2107, 2052, 2055].
# Iteration 31 completed.
#
# The number of labeled samples: [938, 958, 1017, 1008].
# The number of unlabeled samples remaning: [2111, 2091, 2032, 2041].
# Iteration 32 completed.
#
# The number of labeled samples: [947, 966, 1029, 1018].
# The number of unlabeled samples remaning: [2102, 2083, 2020, 2031].
# Iteration 33 completed.
#
# The number of labeled samples: [953, 969, 1035, 1024].
# The number of unlabeled samples remaning: [2096, 2080, 2014, 2025].
# Iteration 34 completed.
#
# The number of labeled samples: [955, 978, 1044, 1031].
# The number of unlabeled samples remaning: [2094, 2071, 2005, 2018].
# Iteration 35 completed.
#
# The number of labeled samples: [961, 980, 1049, 1037].
# The number of unlabeled samples remaning: [2088, 2069, 2000, 2012].
# Iteration 36 completed.
#
# The number of labeled samples: [968, 989, 1057, 1043].
# The number of unlabeled samples remaning: [2081, 2060, 1992, 2006].
# Iteration 37 completed.
#
# The number of labeled samples: [972, 1002, 1070, 1052].
# The number of unlabeled samples remaning: [2077, 2047, 1979, 1997].
# Iteration 38 completed.
#
# The number of labeled samples: [978, 1010, 1079, 1059].
# The number of unlabeled samples remaning: [2071, 2039, 1970, 1990].
# Iteration 39 completed.
#
# The number of labeled samples: [983, 1014, 1082, 1062].
# The number of unlabeled samples remaning: [2066, 2035, 1967, 1987].
# Iteration 40 completed.
#
# The number of labeled samples: [996, 1026, 1103, 1079].
# The number of unlabeled samples remaning: [2053, 2023, 1946, 1970].
# Iteration 41 completed.
#
# The number of labeled samples: [1003, 1032, 1110, 1086].
# The number of unlabeled samples remaning: [2046, 2017, 1939, 1963].
# Iteration 42 completed.
#
# The number of labeled samples: [1013, 1039, 1121, 1094].
# The number of unlabeled samples remaning: [2036, 2010, 1928, 1955].
# Iteration 43 completed.
#
# The number of labeled samples: [1016, 1043, 1124, 1096].
# The number of unlabeled samples remaning: [2033, 2006, 1925, 1953].
# Iteration 44 completed.
#
# The number of labeled samples: [1019, 1045, 1126, 1098].
# The number of unlabeled samples remaning: [2030, 2004, 1923, 1951].
# Iteration 45 completed.
#
# The number of labeled samples: [1022, 1048, 1129, 1098].
# The number of unlabeled samples remaning: [2027, 2001, 1920, 1951].
# Iteration 46 completed.
#
# The number of labeled samples: [1024, 1050, 1131, 1101].
# The number of unlabeled samples remaning: [2025, 1999, 1918, 1948].
# Iteration 47 completed.
#
# The number of labeled samples: [1032, 1053, 1139, 1106].
# The number of unlabeled samples remaning: [2017, 1996, 1910, 1943].
# Iteration 48 completed.
#
# The number of labeled samples: [1037, 1057, 1143, 1108].
# The number of unlabeled samples remaning: [2012, 1992, 1906, 1941].
# Iteration 49 completed.
#
# The number of labeled samples: [1038, 1058, 1143, 1109].
# The number of unlabeled samples remaning: [2011, 1991, 1906, 1940].
# Iteration 50 completed.
#
# The number of labeled samples: [1039, 1059, 1145, 1111].
# The number of unlabeled samples remaning: [2010, 1990, 1904, 1938].
# Iteration 51 completed.
#
# The number of labeled samples: [1043, 1062, 1148, 1113].
# The number of unlabeled samples remaning: [2006, 1987, 1901, 1936].
# Iteration 52 completed.
#
# The number of labeled samples: [1044, 1064, 1150, 1114].
# The number of unlabeled samples remaning: [2005, 1985, 1899, 1935].
# Iteration 53 completed.
#
# The number of labeled samples: [1044, 1064, 1150, 1114].
# The number of unlabeled samples remaning: [2005, 1985, 1899, 1935].
# The algorithm has converged for one or more views. Getting new model parameters.
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'uniform', 'n_neighbors': 10, 'metric': 'dice'}
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'uniform', 'n_neighbors': 22, 'metric': 'dice'}
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'uniform', 'n_neighbors': 30, 'metric': 'dice'}
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'uniform', 'n_neighbors': 35, 'metric': 'jaccard'}
#
# The number of labeled samples: [1045, 1065, 1151, 1114].
# The number of unlabeled samples remaning: [2004, 1984, 1898, 1935].
# Iteration 54 completed.
#
# The number of labeled samples: [1065, 1096, 1170, 1137].
# The number of unlabeled samples remaning: [1984, 1953, 1879, 1912].
# Iteration 55 completed.
#
# The number of labeled samples: [1080, 1114, 1182, 1149].
# The number of unlabeled samples remaning: [1969, 1935, 1867, 1900].
# Iteration 56 completed.
#
# The number of labeled samples: [1089, 1125, 1192, 1155].
# The number of unlabeled samples remaning: [1960, 1924, 1857, 1894].
# Iteration 57 completed.
#
# The number of labeled samples: [1097, 1131, 1195, 1162].
# The number of unlabeled samples remaning: [1952, 1918, 1854, 1887].
# Iteration 58 completed.
#
# The number of labeled samples: [1100, 1146, 1211, 1176].
# The number of unlabeled samples remaning: [1949, 1903, 1838, 1873].
# Iteration 59 completed.
#
# The number of labeled samples: [1106, 1155, 1215, 1184].
# The number of unlabeled samples remaning: [1943, 1894, 1834, 1865].
# Iteration 60 completed.
#
# The number of labeled samples: [1111, 1161, 1217, 1189].
# The number of unlabeled samples remaning: [1938, 1888, 1832, 1860].
# Iteration 61 completed.
#
# The number of labeled samples: [1122, 1173, 1219, 1200].
# The number of unlabeled samples remaning: [1927, 1876, 1830, 1849].
# Iteration 62 completed.
#
# The number of labeled samples: [1122, 1174, 1220, 1201].
# The number of unlabeled samples remaning: [1927, 1875, 1829, 1848].
# Iteration 63 completed.
#
# The number of labeled samples: [1126, 1177, 1221, 1205].
# The number of unlabeled samples remaning: [1923, 1872, 1828, 1844].
# Iteration 64 completed.
#
# The number of labeled samples: [1126, 1177, 1221, 1205].
# The number of unlabeled samples remaning: [1923, 1872, 1828, 1844].
# The algorithm has converged for one or more views. Getting new model parameters.
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'uniform', 'n_neighbors': 17, 'metric': 'dice'}
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'uniform', 'n_neighbors': 32, 'metric': 'dice'}
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'uniform', 'n_neighbors': 27, 'metric': 'jaccard'}
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'uniform', 'n_neighbors': 37, 'metric': 'dice'}
#
# The number of labeled samples: [1128, 1179, 1221, 1207].
# The number of unlabeled samples remaning: [1921, 1870, 1828, 1842].
# Iteration 65 completed.
#
# The number of labeled samples: [1133, 1187, 1224, 1215].
# The number of unlabeled samples remaning: [1916, 1862, 1825, 1834].
# Iteration 66 completed.
#
# The number of labeled samples: [1140, 1194, 1224, 1222].
# The number of unlabeled samples remaning: [1909, 1855, 1825, 1827].
# Iteration 67 completed.
#
# The number of labeled samples: [1140, 1194, 1224, 1222].
# The number of unlabeled samples remaning: [1909, 1855, 1825, 1827].
# The algorithm has converged for one or more views. Getting new model parameters.
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'uniform', 'n_neighbors': 17, 'metric': 'dice'}
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'uniform', 'n_neighbors': 32, 'metric': 'jaccard'}
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'uniform', 'n_neighbors': 27, 'metric': 'dice'}
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'uniform', 'n_neighbors': 37, 'metric': 'dice'}
#
# The number of labeled samples: [1142, 1196, 1224, 1224].
# The number of unlabeled samples remaning: [1907, 1853, 1825, 1825].
# Iteration 68 completed.
#
# The number of labeled samples: [1143, 1197, 1225, 1224].
# The number of unlabeled samples remaning: [1906, 1852, 1824, 1825].
# Iteration 69 completed.
#
# The number of labeled samples: [1146, 1200, 1225, 1227].
# The number of unlabeled samples remaning: [1903, 1849, 1824, 1822].
# Iteration 70 completed.
#
# The number of labeled samples: [1146, 1200, 1225, 1227].
# The number of unlabeled samples remaning: [1903, 1849, 1824, 1822].
# The algorithm has converged for one or more views. Getting new model parameters.
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'uniform', 'n_neighbors': 40, 'metric': 'jaccard'}
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'uniform', 'n_neighbors': 20, 'metric': 'dice'}
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'uniform', 'n_neighbors': 35, 'metric': 'jaccard'}
#
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# {'weights': 'uniform', 'n_neighbors': 35, 'metric': 'dice'}
#
# The number of labeled samples: [1146, 1200, 1225, 1227].
# The number of unlabeled samples remaning: [1903, 1849, 1824, 1822].

# %% [markdown]
# ### Plot Accuracy and F1-Score

# %%
# plot training accuracy over epochs
plt.figure(figsize = (10,6))
plt.plot(test_acc_list, color = 'Green')
plt.xlabel('Iterations', fontdict = {'fontsize': 12})
plt.ylabel('Test Accuracy', fontdict = {'fontsize': 12})
plt.title('Test Accuracy over increasing iterations.')
plt.grid()

# %%
# plot training accuracy over epochs
plt.figure(figsize = (10,6))
plt.plot(test_f1_list, color = 'Green')
plt.xlabel('Iterations', fontdict = {'fontsize': 12})
plt.ylabel('Test F1-Score', fontdict = {'fontsize': 12})
plt.title('Test F1-Score over increasing iterations')
plt.grid()

# %%
acc, f1_sc = print_individual_test_accuracies(final_models_list, verbose = 1)
# Out:
# Model 1: Accuracy: 0.727 and F1-score: 0.794.
# Model 2: Accuracy: 0.720 and F1-score: 0.795.
# Model 3: Accuracy: 0.720 and F1-score: 0.793.
# Model 4: Accuracy: 0.708 and F1-score: 0.783.
#
# Average test accuracy: 0.708
# Average F1-score: 0.783
